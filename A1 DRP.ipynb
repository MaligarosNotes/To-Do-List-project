# %%
import numpy as np
import math 
import pandas as pd
import matplotlib 
import yfinance as yf

# %%
aapl = yf.Ticker("AAPL")
hist = aapl.history(period="max")
hist.head()
# Out:
# $AAPL: possibly delisted; no price data found  (1d 1926-10-19 -> 2025-09-24)
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
