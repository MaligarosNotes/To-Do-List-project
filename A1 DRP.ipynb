# %%
import numpy as np
import math 
import pandas as pd
import matplotlib 
import yfinance as yf

# %%
#so the todo is the literal task and the day i make it, not the due date, and a check box
class todo:
    def __init__(self, task, date, completed=False):
        self.task = task
        self.date = date
        self.completed = completed
    def mark_complete(self):
        self.completed = True

# todo_list is a list of todo objects
class todo_list:
    def __init__(self):
        self.todos = []
    def import_todos(self, todo_data):
        for task, date, completed in todo_data:
            new_todo = todo(task, date, completed)
            self.todos.append(new_todo)
    def add_todo(self, task, date):
        new_todo = todo(task, date)
        self.todos.append(new_todo)
    def get_incomplete_todos(self):
        return [t for t in self.todos if not t.completed]
    def export_todos(self):
        return [(t.task, t.date, t.completed) for t in self.todos]
    
Maligaro_todos = todo_list()
Maligaro_todos.add_todo("Finish project", "2024-06-30")
Maligaro_todos.add_todo("Study for exam", "2024-07-05")
incomplete = Maligaro_todos.get_incomplete_todos()
print(incomplete)
# Out:
# [<__main__.todo object at 0x112a99280>, <__main__.todo object at 0x112a641d0>]

# %%
# this part is for displaying list data or smth. maybe like csv data idk
# also the database stuff ig
